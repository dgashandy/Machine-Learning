# %% [markdown]
# # **Tugas 1 Machine Learning**

# %% [markdown]
# # Import dan Analisis Data

# %%
import pandas as pd
from scipy import stats
import seaborn as sb

# %% [markdown]
# Load data .csv

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-eb0ef2e0-043f-4025-82dc-5f9fee9a3057" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb0ef2e0-043f-4025-82dc-5f9fee9a3057">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Death Cause Reason by Country.csv to Death Cause Reason by Country.csv

# %%
import io
df = pd.read_csv(io.BytesIO(data_to_load['Death Cause Reason by Country.csv']))

# %% [markdown]
# Read data .csv

# %%
data = pd.read_csv("Death Cause Reason by Country.csv")
data
# Out:
#     Country Name  Covid-19 Deaths  Cardiovascular diseases  \
# 0    Afghanistan           2201.0                    61995
# 1        Albania           1181.0                    12904
# 2        Algeria           2762.0                    97931
# 3        Andorra             84.0                      169
# 4         Angola             33.0                    25724
# ..           ...              ...                      ...
# 186      Vietnam             35.0                   240161
# 187        Wales            512.0                    10519
# 188        Yemen            610.0                    55752
# 189       Zambia            390.0                    18157
# 190     Zimbabwe            369.0                    17810
#
#      Respiratory diseases   Kidney diseases  Neonatal disorders   Meningitis   \
# 0                     7082             5637                23701         1563
# 1                      815              329                  161           13
# ...

# %%
data.shape
# Out:
# (191, 33)

# %% [markdown]
# Menampilkan List dari Kolom

# %%
data.columns
# Out:
# Index(['Country Name', 'Covid-19 Deaths', 'Cardiovascular diseases',
#        'Respiratory diseases ', 'Kidney diseases', 'Neonatal disorders ',
#        'Meningitis ', 'Malaria ', 'Interpersonal violence', 'HIV/AIDS',
#        'Tuberculosis', 'Maternal disorders', 'Lower respiratory infections',
#        'Alcohol use disorders', 'Diarrheal diseases', 'Poisoning',
#        'Nutritional deficiencies', ' Alzheimer's disease',
#        'Parkinson's disease', ' Acute hepatitis', 'Digestive diseases',
#        ' Cirrhosis and other chronic liver diseases',
#        'Protein-energy malnutrition', 'Neoplasms', 'Fire, heat', 'Drowning',
#        'Drug use disorders', 'Road injuries',
#        'Environmental heat and cold exposure', 'Self-harm',
#        ' Conflict and terrorism', 'Diabetes ', 'Unnamed: 32'],
#       dtype='object')

# %% [markdown]
# Identifikasi tipe data dari masing masing kolom

# %%
data.dtypes
# Out:
# Country Name                                    object
# Covid-19 Deaths                                float64
# Cardiovascular diseases                          int64
# Respiratory diseases                             int64
# Kidney diseases                                  int64
# Neonatal disorders                               int64
# Meningitis                                       int64
# Malaria                                          int64
# Interpersonal violence                           int64
# HIV/AIDS                                         int64
# Tuberculosis                                     int64
# Maternal disorders                               int64
# Lower respiratory infections                     int64
# Alcohol use disorders                            int64
# Diarrheal diseases                               int64
# Poisoning                                        int64
# Nutritional deficiencies                         int64
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country Name                                 191 non-null    object
#  1   Covid-19 Deaths                              188 non-null    float64
#  2   Cardiovascular diseases                      191 non-null    int64
#  3   Respiratory diseases                         191 non-null    int64
#  4   Kidney diseases                              191 non-null    int64
#  5   Neonatal disorders                           191 non-null    int64
#  6   Meningitis                                   191 non-null    int64
#  7   Malaria                                      191 non-null    int64
#  8   Interpersonal violence                       191 non-null    int64
# ...

# %%
data.isna().values.any()
# Out:
# True

# %% [markdown]
# Mengidentifikasikan Duplikasi pada Baris/Entri

# %%
data.duplicated()
# Tidak ada duplikasi pada masing-masing entry/baris, sehingga tidak ada yang perlu di drop
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# Length: 191, dtype: bool

# %% [markdown]
# Mendeskripsikan Dataset

# %%
data.describe(include='all')
# Didapat Frekuensi, Mean, Standar Deviasi, Nilai Tertinggi dan Terendah, Serta Quartil(q1,q2,q3) pada fungsi .describe()
# Out:
#        Country Name  Covid-19 Deaths  Cardiovascular diseases  \
# count           191       188.000000             1.910000e+02
# unique          191              NaN                      NaN
# top     Afghanistan              NaN                      NaN
# freq              1              NaN                      NaN
# mean            NaN     10461.404255             9.808936e+04
# std             NaN     35107.423980             3.956782e+05
# min             NaN         1.000000             8.000000e+00
# 25%             NaN        84.750000             4.648500e+03
# 50%             NaN       612.500000             1.815700e+04
# 75%             NaN      3986.750000             5.737250e+04
# max             NaN    353948.000000             4.584273e+06
#
#         Respiratory diseases   Kidney diseases  Neonatal disorders   \
# count            1.910000e+02       191.000000           191.000000
# unique                    NaN              NaN                  NaN
# ...

# %%
#Mencari Median pada Data Set
data.median().sort_values(ascending =False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Cardiovascular diseases                        18157.0
# Neoplasms                                      10084.0
# Digestive diseases                              3226.0
# Respiratory diseases                            2529.0
# Lower respiratory infections                    2454.0
# Diabetes                                        1899.0
# Kidney diseases                                 1813.0
#  Cirrhosis and other chronic liver diseases     1809.0
#  Alzheimer's disease                            1295.0
# Road injuries                                   1049.0
# Self-harm                                        671.0
# Covid-19 Deaths                                  612.5
# ...

# %%
#Mencari Mean pada Dataset
data.mean().sort_values(ascending =False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Cardiovascular diseases                        98089.361257
# Neoplasms                                      53728.209424
# Respiratory diseases                           21042.418848
# Digestive diseases                             13517.874346
# Lower respiratory infections                   13151.413613
# Covid-19 Deaths                                10461.404255
# Neonatal disorders                              9759.513089
#  Alzheimer's disease                            8665.931937
# Diabetes                                        8120.701571
# Diarrheal diseases                              7933.884817
#  Cirrhosis and other chronic liver diseases     7735.287958
# ...

# %%
# Mencari Varian pada Dataset
data.var().sort_values(ascending =False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Cardiovascular diseases                        1.565612e+11
# Neoplasms                                      4.816951e+10
# Respiratory diseases                           1.351064e+10
# Diarrheal diseases                             2.318126e+09
# Digestive diseases                             1.829249e+09
# Neonatal disorders                             1.578447e+09
# Lower respiratory infections                   1.494522e+09
# Covid-19 Deaths                                1.232531e+09
# Tuberculosis                                   1.018788e+09
#  Alzheimer's disease                           9.161224e+08
# Diabetes                                       6.903830e+08
# ...

# %%
# Mencari Modus pada Dataset
data.mode()
# Out:
#     Country Name  Covid-19 Deaths  Cardiovascular diseases  \
# 0    Afghanistan              3.0                  29709.0
# 1        Albania              NaN                      NaN
# 2        Algeria              NaN                      NaN
# 3        Andorra              NaN                      NaN
# 4         Angola              NaN                      NaN
# ..           ...              ...                      ...
# 186      Vietnam              NaN                      NaN
# 187        Wales              NaN                      NaN
# 188        Yemen              NaN                      NaN
# 189       Zambia              NaN                      NaN
# 190     Zimbabwe              NaN                      NaN
#
#      Respiratory diseases   Kidney diseases  Neonatal disorders   Meningitis   \
# 0                     11.0            706.0                  0.0          0.0
# 1                      NaN              NaN                  1.0          NaN
# ...

# %%
data.corr()
# Out:
#                                              Covid-19 Deaths  \
# Covid-19 Deaths                                     1.000000
# Cardiovascular diseases                             0.328140
# Respiratory diseases                                0.344193
# Kidney diseases                                     0.546666
# Neonatal disorders                                  0.246353
# Meningitis                                          0.149297
# Malaria                                            -0.010681
# Interpersonal violence                              0.640737
# HIV/AIDS                                            0.116104
# Tuberculosis                                        0.273676
# Maternal disorders                                  0.235969
# Lower respiratory infections                        0.433577
# Alcohol use disorders                               0.556959
# Diarrheal diseases                                  0.279989
# ...

# %% [markdown]
# Visualisasi Data

# %%
sns.heatmap(data.corr())

# %%
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv("Death Cause Reason by Country.csv")
data.corr().hist(bins = 10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1f3ceb110>,
# ...
#       dtype=object)

# %% [markdown]
# **Analisa Korelasi Fitur**

# %% [markdown]
# Korelasi Covid-19 dengan Penyakit Cardio

# %%
data = pd.read_csv("Death Cause Reason by Country.csv")
data.hist(column = 'Covid-19 Deaths',bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1cbbf0b90>]],
#       dtype=object)

# %%
import seaborn as sns
data = pd.read_csv("Death Cause Reason by Country.csv")
sns.regplot(x="Cardiovascular diseases",y="Covid-19 Deaths",data=data)

# %%
data[["Covid-19 Deaths","Cardiovascular diseases"]].corr()
# Out:
#                          Covid-19 Deaths  Cardiovascular diseases
# Covid-19 Deaths                  1.00000                  0.32814
# Cardiovascular diseases          0.32814                  1.00000

# %% [markdown]
# Korelasi penyakit Pernapasan dengan Penyakit Lambung

# %%
import seaborn as sns
sns.regplot(x="Kidney diseases",y="Cardiovascular diseases",data=data)

# %%
data[["Kidney diseases","Covid-19 Deaths"]].corr()
# Out:
#                  Kidney diseases  Covid-19 Deaths
# Kidney diseases         1.000000         0.546666
# Covid-19 Deaths         0.546666         1.000000

# %% [markdown]
# Korelasi antara Meningitis dan Malaria

# %%
sns.regplot(x="Meningitis ",y="Malaria ",data=data)

# %%
data[["Meningitis ","Malaria "]].corr()
# Out:
#              Meningitis   Malaria
# Meningitis      1.000000  0.817297
# Malaria         0.817297  1.000000
